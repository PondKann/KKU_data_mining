# %% [markdown]
# <a href="https://colab.research.google.com/github/PondKann/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import pandas as pd
base_path = '/content/drive/My Drive/DWDM_material'
data = pd.read_csv(os.path.join(base_path,'test.csv'))
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# # Box plot

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# นำแกน x มาสร้าง boxplot

# %%
plt.boxplot(data['x'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fa4b19019e8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa4b1898438>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa4b1898eb8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa4b1898b38>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fa4b1901cf8>,
#   <matplotlib.lines.Line2D at 0x7fa4b18980b8>]}

# %% [markdown]
# ใส่ vert เพื่อในกล่องอยู่ในแนวนอน

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fa4b13e4048>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa4b13e4a58>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa4b13f0518>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa4b13f0198>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fa4b13e4358>,
#   <matplotlib.lines.Line2D at 0x7fa4b13e46d8>]}

# %% [markdown]
# เปลี่ยน whisker เป็น 1.2 ให้มี ค่า out lier ให้มีมากกว่าเดิม

# %%
plt.boxplot(data['x'],vert=False,whis=1.2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fa4b14057b8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa4b185c780>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa4b13e4080>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa4b1399080>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fa4b14058d0>,
#   <matplotlib.lines.Line2D at 0x7fa4b185cac8>]}

# %%
oput = plt.boxplot(data['x'],vert=False,whis=1.2)

# %% [markdown]
# ดูค่าที่มัน มากกว่า 1.2IQR (ค่า outlier)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %% [markdown]
# เส้น whisker วาดจากค่า Q1(=44.1026) ถึง 1.2IQR(=22.3077) (1.2 เรากำหนดใหม่ ปกติเป็น 1.5)

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=25)

# %% [markdown]
# ขนาดของจุดเป็นไปตามค่า y ยิ่งค่า y มาก ขนาดจะยิ่งใหญ่

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %% [markdown]
# เพิ่ม c = จุดเป็นสีต่าง ๆ

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m',marker='*')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m',marker='*',alpha=0.4)
plt.scatter([44,42,50],[15,14,80],s=50,alpha=0.6)

# %% [markdown]
# # HW4 วาดปีกกับนอ ให้ไดโนเสาร์

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='#FF6666',marker='*',alpha=1)
plt.scatter([49],[82],s=50,alpha=0.9)
plt.scatter([45,47],[11,9],s=50,alpha=1)
plt.scatter([37,35,33,31,29,27,28,29,30],[83,83,83,83,83,83,80,78,76],s=50,alpha=0.6,c = 'DimGrey' )
plt.scatter([82,83,84,85,86,87,88,89],[43,47,51,54,57,60,63,66],s=50,alpha=0.6,c='#6600FF')
plt.scatter([90,91],[69,71],s=50,alpha=0.6,c='#6666FF')
plt.scatter([92,93,94,95,96,97,98,98,99,100,101,102,102,101,],[72,73,73,72,71,69,66,64,64,64,63,61,59,56],s=50,alpha=0.6,c='#6699FF')
plt.scatter([100,99],[54,53],alpha=0.6,c='#6666FF')
plt.scatter([98,96,95,94,93,92,91,90],[52,51,50,48,46,44,42,40],s=50,alpha=0.6,c='#6600FF')
plt.scatter([83,84,85,86,87,88],[63,66,69,71,72,73],s=50,alpha=0.6,c='#6600FF')
plt.scatter([89,91,92],[75,75,74],alpha=0.6,c='#6666FF')

# %% [markdown]
# # Plot

# %%
plt.plot(data['x'],data['y'])

# %% [markdown]
# r สีแดง 0 จุด -เส้น

# %%
plt.plot(data['x'],data['y'],'ro-')

# %%
#หาจุดแรกของรูป
plt.plot(data['x'],data['y'],'ro-')
plt.scatter(data['x'][0],data['y'][0],s=200, c='k' )

# %%
plt.plot(data['x'],data['y'],'r-')
#วาดจุดแรกไปจุดสุดท้าย โดยให้เพิ่มขนาดของจุดเริ่มจาก 10 ให้ลำลับของมัน เพิ่มไปทีละ 10 เช่น ลำดับ 0+10, ลำดับ 1+10 
plt.scatter(data['x'],data['y'],s=range(10,len(data['x'])+10))

# %%
plt.scatter(data['x'],data['y'],s=250,c=[[0.5,1,0.9,0.5]])

# %%
color_list = []

# %%
#เริ่มจาก 0 ไปจนถึงลำดับสุดท้ายของข้อมูล
for i in range(len(data['x'])):
    color_list.append([0.2,0.1,i/255,0.5]) #ค่อยๆเพิ่มสีน้ำเงิน
color_list
# Out:
# [[0.2, 0.1, 0.0, 0.5],
#  [0.2, 0.1, 0.00392156862745098, 0.5],
#  [0.2, 0.1, 0.00784313725490196, 0.5],
#  [0.2, 0.1, 0.011764705882352941, 0.5],
#  [0.2, 0.1, 0.01568627450980392, 0.5],
#  [0.2, 0.1, 0.0196078431372549, 0.5],
#  [0.2, 0.1, 0.023529411764705882, 0.5],
#  [0.2, 0.1, 0.027450980392156862, 0.5],
#  [0.2, 0.1, 0.03137254901960784, 0.5],
#  [0.2, 0.1, 0.03529411764705882, 0.5],
#  [0.2, 0.1, 0.0392156862745098, 0.5],
#  [0.2, 0.1, 0.043137254901960784, 0.5],
#  [0.2, 0.1, 0.047058823529411764, 0.5],
#  [0.2, 0.1, 0.050980392156862744, 0.5],
#  [0.2, 0.1, 0.054901960784313725, 0.5],
#  [0.2, 0.1, 0.058823529411764705, 0.5],
#  [0.2, 0.1, 0.06274509803921569, 0.5],
#  [0.2, 0.1, 0.06666666666666667, 0.5],
#  [0.2, 0.1, 0.07058823529411765, 0.5],
#  [0.2, 0.1, 0.07450980392156863, 0.5],
#  [0.2, 0.1, 0.0784313725490196, 0.5],
#  [0.2, 0.1, 0.08235294117647059, 0.5],
#  [0.2, 0.1, 0.08627450980392157, 0.5],
#  [0.2, 0.1, 0.09019607843137255, 0.5],
# ...

# %%
plt.scatter(data['x'],data['y'],s=250,c=color_list)

# %% [markdown]
# # Bar chart

# %%
# เรียกใช้ฟังก์ชันที่จำเป็น
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

# %%
fig, ax = plt.subplots()
# + - คือให้ข้อมูลเลื่อนไปซ้ายครึ่งนึง ขวาครึ่งนึง 
rects1 = ax.bar(x - width/2, men_means, width, label='Men') 
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores') #ตั้งชื่อให้แกน Y 
ax.set_title('Scores by group and gender') #ตั้งชื่อ กราฟ

# เปลี่ยนค่าแกน x ให้เป็นตาม lebels ที่เรากำหนดไว้ ต้องมาด้วยกันทั้ง2บรรทัด
ax.set_xticks(x)
ax.set_xticklabels(labels); # ใส่; เพื่อบอกว่าจบแล้วไม่ต้องปริ้นอะไร
ax.legend() # เพิ่มคำอธิบายแต่ละเส้นของกราฟ

# %%
plt.bar(x - width/2, men_means, width, label='Men') 
plt.bar(x + width/2, women_means, width, label='Women')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.legend();

# %% [markdown]
# ## Histogram

# %%
x = [12,25,7,7,1,1,1,1,5,5,5,5,]

# %%
plt.hist(x)
# Out:
# (array([4., 4., 2., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist('a a a a g t t f f h h c v b b b b b b m m m' .split()) # .spit แยกตาม ช่องว่าง
# Out:
# (array([4., 1., 2., 2., 0., 2., 1., 1., 6., 3.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <a list of 10 Patch objects>)
